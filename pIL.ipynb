# %%
import numpy as np 
import pandas as pd 
import scipy as py
from scipy import misc ,ndimage
import matplotlib.pyplot as plt
from PIL import Image
import scipy.ndimage as nd 
from scipy.cluster.vq import whiten
import imageio

# %%
from PIL import Image
#load the image 
image = Image.open("")
#summarize some details about the image
print(image.format)
print(image.mode)
print(image.size)
#convert the imgage to gryscale
gs_image = image.convert(mode='L')
#save in jpeg format
gs_image.save('')
#resize image and ignore original aspect ratio
img_resize = image.resize((200,200))
#load the image again and show it
image2 = Image.open('')
#show the image
image.show()
img_resize.show()

# %%
f = misc.face()
imageio.imsave('face.png',f)
plt.imshow(f)
plt.show()
# Out:
# C:\Users\SunInternet.ir\AppData\Local\Temp\ipykernel_4204\1172488120.py:1: DeprecationWarning: scipy.misc.face has been deprecated in SciPy v1.10.0; and will be completely removed in SciPy v1.12.0. Dataset methods have moved into the scipy.datasets module. Use scipy.datasets.face instead.
#   f = misc.face()

# %%
face = misc.face(gray = False)
print(face.mean(),face.max(),face.min())
# Out:
# C:\Users\SunInternet.ir\AppData\Local\Temp\ipykernel_4204\2089006435.py:1: DeprecationWarning: scipy.misc.face has been deprecated in SciPy v1.10.0; and will be completely removed in SciPy v1.12.0. Dataset methods have moved into the scipy.datasets module. Use scipy.datasets.face instead.
#   face = misc.face(gray = False)
# 110.16274388631184 255 0

# %%
face = misc.face(gray=False)
lx, ly, _ = face.shape 

# Cropping
crop_face = face[lx // 4: -lx // 4, ly // 4: -ly // 4, :]
plt.imshow(crop_face)
plt.show()
# Out:
# C:\Users\SunInternet.ir\AppData\Local\Temp\ipykernel_4204\1248421168.py:1: DeprecationWarning: scipy.misc.face has been deprecated in SciPy v1.10.0; and will be completely removed in SciPy v1.12.0. Dataset methods have moved into the scipy.datasets module. Use scipy.datasets.face instead.
#   face = misc.face(gray=False)

# %%
face = misc.face()
burred_face = ndimage.gaussian_filter(face,sigma=7)
plt.imshow(burred_face)
plt.show()
# Out:
# C:\Users\SunInternet.ir\AppData\Local\Temp\ipykernel_4204\676011308.py:1: DeprecationWarning: scipy.misc.face has been deprecated in SciPy v1.10.0; and will be completely removed in SciPy v1.12.0. Dataset methods have moved into the scipy.datasets module. Use scipy.datasets.face instead.
#   face = misc.face()

# %%
# f = misc.face()
# imageio.imsave('face.png',f)
# imx = np.zeros(im.shape)
# ndimage.sobel(im,1,imx)
# imy = np.zeros(im.shape)
# ndimage.sobel(im,0,imy)
# magnitude =  np.sqrt(imx**2+imy**2)
# plt.imshow(magnitude)
# plt.show()
f = misc.face()
imageio.imsave('face.png', f)
im = imageio.imread('face.png')

imx = np.zeros(im.shape)
ndimage.sobel(im, 1, imx)
imy = np.zeros(im.shape)
# Out:
# C:\Users\SunInternet.ir\AppData\Local\Temp\ipykernel_4204\2208822096.py:10: DeprecationWarning: scipy.misc.face has been deprecated in SciPy v1.10.0; and will be completely removed in SciPy v1.12.0. Dataset methods have moved into the scipy.datasets module. Use scipy.datasets.face instead.
#   f = misc.face()
# C:\Users\SunInternet.ir\AppData\Local\Temp\ipykernel_4204\2208822096.py:12: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   im = imageio.imread('face.png')

# %%
# f = misc.face()
# imageio.imsave('face.png',f)
# sigma = 5
# try:
#     imx = np.zeros(im.shape)
#     ndimage.gaussian_filter(im,(sigma,sigma),(0,1),imx)
#     imy = np.zeros(im.shape)
#     ndimage.gaussian_filter(im,(sigma,sigma),(0,1),imy)
# except:
#     pass
# plt.imshow(magntude)
# plt.show()


from scipy import misc, ndimage
import imageio
import numpy as np
import matplotlib.pyplot as plt

# Load the image
f = misc.face()
imageio.imsave('face.png', f)
im = imageio.imread('face.png')

# Define sigma for Gaussian filter
sigma = 5

# Apply Gaussian filtering along x-axis (horizontal)
imx = ndimage.gaussian_filter(im, sigma=sigma, order=0)

# Apply Gaussian filtering along y-axis (vertical)
imy = ndimage.gaussian_filter(im, sigma=sigma, order=0)

# Compute magnitude of gradients
magnitude = np.sqrt(imx**2 + imy**2)

# Display the magnitude
plt.imshow(magnitude, cmap='gray')
plt.show()

# %%
myimage = np.zeros((256,256))
myimage[30:-30,30:-30] = 4
myimage[90:-90,90:-90] = 5
myimage = ndimage.gaussian_filter(myimage,10)
plt.imshow(myimage)
plt.show()
