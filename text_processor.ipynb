# %% [markdown]
# ## Natural language technology

# %%
import pandas as pd

# %% [markdown]
# ## read the data set

# %%
df = pd.read_csv(r'/home/ali/Desktop/train.csv')

# %%
df
# Out:
#                                                     title     subgroup  \
# 0       پلیس: جرائم خشن و مسلحانه در تهران کاهش یافته است        عمومی
# 1       وزیر بهداشت:\r\nآغاز اجرای طرح جامع "دارویار"/...  اخبار سلامت
# 2       وزارت بهداشت: قیمت دارو برای مصرف کننده ثابت م...      اجتماعی
# 3       معاون رئیسی: مردم به زودی شاهد اثرات مثبت اقدا...        سیاسی
# 4        دستگیری سارق ۲۰ هزار دلاری ارز دیجیتال در گلستان      اجتماعی
# ...                                                   ...          ...
# 237879      معاون وزیر ارشاد: مخالف انحصار صداوسیما هستیم        سیاسی
# 237880  دیدار دست‌اندرکاران همایش حکیم تهران با مقام م...        سیاسی
# 237881  ترامپ: هنگام امضای برجام باید به سوریه و یمن ن...  سیاست خارجی
# 237882             واردات گوشی تلفن همراه از خودرو جلو زد      اقتصادی
# 237883               نرخ بیکاری جوانان بیش از 25 درصد است      اقتصادی
#
#                                                  abstract  \
# 0       آمارهای پلیس نشان می‌دهد که جرائم خشن و مسلحان...
# 1       هدف اصلی وزارت بهداشت از این طرح این است که پو...
# 2                                                     NaN
# 3       معاون امور مجلس رئیس جمهور: استان گیلان دارای ...
# 4       شهروندان توصیه‌های پلیس فتا را جدی بگیرند و در...
# ...                                                   ...
# 237879  قطعا با هرگونه انحصار در فعالیت‌های فراگیر مرد...
# 237880  حذف فلسفه از حوزه علمیه قم موجب خواهد شد افراد...
# 237881  ترامپ برجام را یک توافق بد توصیف و تصریح کرد: ...
# 237882  در فروردین ماه امسال­­ تعداد 249 هزار و 154 دس...
# 237883  اولین گام مهم و مورد نیاز ترمیم بنگاه های در ح...
#
#                                                      body
# 0       رئیس پلیس آگاهی تهران بزرگ اعلام کرد که موضوع ...
# 1       وزیر بهداشت جزییات طرح "دارویار" که اجرای آن آ...
# 2       سخنگوی وزارت بهداشت، درمان و آموزش پزشکی در تو...
# 3       معاون رئیس جمهور گفت: دولت برنامه های راهبردی ...
# 4       رییس پلیس فتا فرماندهی انتظامی گلستان گفت: سار...
# ...                                                   ...
# 237879  معاون مطبوعاتی وزیر ارشاد گفت: انحصار صدور مجو...
# 237880  پایگاه اطلاع رسانی مقام معظم رهبری نوشت: بیانا...
# 237881  رئیس‌جمهور آمریکا بار دیگر با انتقاد از برجام ...
# 237882  براساس آمار گمرک ایران در­ فروردین ماه امسال ­...
# 237883  حمید حاج اسماعیلی کارشناس کار و تحلیلگر اقتصاد...
#
# [237884 rows x 4 columns]

# %%
value_see = df['subgroup'].value_counts()

# %%
value_see
# Out:
# subgroup
# اجتماعی                  74811
# بین الملل                37954
# سیاسی                    28737
# اقتصادی                  27380
# ورزشی                    17807
# فرهنگی/هنری              10814
# سیاست خارجی               7959
# حوادث                     7649
# سلامت                     6937
# خواندنی ها و دیدنی ها     6618
# عمومی                     4829
# فناوری و IT               2193
# علمی                      1850
# روانشناسی                  497
# اخبار سلامت                496
# محیط زیست                  436
# سرگرمی                     310
# دانلود                     258
# سفر و تفریح                142
# داستان کوتاه               135
# آشپزی                       29
# کاربران                     25
# پیامک                       18
# Name: count, dtype: int64

# %%
value_specific_social = df[df['subgroup']=='اجتماعی']

# %%
value_specific_social.head()
# Out:
#                                                 title subgroup  \
# 2   وزارت بهداشت: قیمت دارو برای مصرف کننده ثابت م...  اجتماعی
# 4    دستگیری سارق ۲۰ هزار دلاری ارز دیجیتال در گلستان  اجتماعی
# 9   پلیس فتا: تشدید مقابله با لایوهای غیر اخلاقی د...  اجتماعی
# 13  سخنان درست رحیم‌پور ازغدی و قالیباف دربارۀ مسأ...  اجتماعی
# 17       گزارش روزنامه «اعتماد» از تقلب در کنکور ۱۴۰۰  اجتماعی
#
#                                              abstract  \
# 2                                                 NaN
# 4   شهروندان توصیه‌های پلیس فتا را جدی بگیرند و در...
# 9   رصد این گونه جریانات غیر اخلاقی که مغایر با شئ...
# 13  « اشتباه کردیم حجاب را بین صفر و صد محدود کردی...
# 17  در یکی از مهم‌ترین و امن‌ترین آزمون‌های سراسری...
#
#                                                  body
# 2   سخنگوی وزارت بهداشت، درمان و آموزش پزشکی در تو...
# 4   رییس پلیس فتا فرماندهی انتظامی گلستان گفت: سار...
# 9   معاون فرهنگی اجتماعی پلیس فتا فراجا از تشدید ط...
# 13  -  کانال تلگرام قرارگاه سایبری عمار ویدیوی یکی...
# 17  روزنامه اعتماد در گزارشی مدعی شده است شماری از...

# %%
value_specific_international = df[df['subgroup']=='بین الملل']

# %%
value_specific_international.head()
# Out:
#                                                 title   subgroup  \
# 14                                 به کعبه دست نزنید!  بین الملل
# 25              اوکراین روابط خود را با سوریه قطع کرد  بین الملل
# 26  واکنش سازمان ملل به تصمیم سوریه در به‌ رسمیت ش...  بین الملل
# 35  نیویورک تایمز: ترامپ به‌ زودی نامزدیش در انتخا...  بین الملل
# 50  دولت جدید در اسرائیل/ کنست منحل شد / انتخابات ...  بین الملل
#
#                                              abstract  \
# 14  اما در شهر مدینه و در مسجدالنبی و قبرستان بقیع...
# 25  لازم به ذکر است که وزارت خارجه سوریه پیش از ای...
# 26  وزارت خارجه سوریه روز چهارشنبه از تصمیم خود بر...
# 35  نیویورک تایمز علت این اقدام ترامپ را رقابت با ...
# 50  سه شنبه ، کنست اولین قرائت را برای انحلال خود ...
#
#                                                  body
# 14  عربستان اگر چه حج را پس از دو سال با کمترین مح...
# 25  رئیس جمهور اوکراین از قطع روابط این کشور با سو...
# 26  سازمان ملل به تصمیم دولت سوریه برای به رسمیت ش...
# 35  دونالد ترامپ در نظر دارد به منظور منحرف کردن ت...
# 50  رسانه‌های اسرائیل منتظر اعلام رسمی انحلال کنست...

# %%
value_specific_political = df[df['subgroup']=='سیاسی']

# %%
value_specific_political.head()
# Out:
#                                                 title subgroup  \
# 3   معاون رئیسی: مردم به زودی شاهد اثرات مثبت اقدا...    سیاسی
# 6   معاون وزیر اطلاعات: فضای مجازی بلای خانمان سوز...    سیاسی
# 7   آبکش شدن با 60 گلوله پلیس؛ تاوان فرار یک جوان ...    سیاسی
# 18  چرا بهشتی دستور آزادی همسر و دختر بازداشتی بنی...    سیاسی
# 21  قرارگاه خاتم‌الانبیاء سپاه، پیمانکار راه‌آهن ا...    سیاسی
#
#                                              abstract  \
# 3   معاون امور مجلس رئیس جمهور: استان گیلان دارای ...
# 6   مقام معظم رهبری بیان کردند اگر رهبر نبودند مسئ...
# 7   خانواده این جوان 25 ساله آمریکایی گفته اند رفت...
# 18  شهید بهشتی فرمود آزادشان کنید، آدم، رقیب سیاسی...
# 21  وی اضافه کرد: طبق توافق صورت گرفته، مقرر شد که...
#
#                                                  body
# 3   معاون رئیس جمهور گفت: دولت برنامه های راهبردی ...
# 6   معاون سیاسی، فرهنگی و اجتماعی وزارت اطلاعات گف...
# 7   یک جوان سیاه پوست در شهر آکرون ایالت اوهایو آم...
# 18  ایرنا نوشت : استاد حوزه و دانشگاه با اشاره به ...
# 21  نماینده مردم اردبیل، نمین، نیر و سرعین در مجلس...

# %%
value_specific_economic = df[df['subgroup']=='اقتصادی']

# %%
value_specific_economic.head()
# Out:
#                                                 title subgroup  \
# 12  هزینه خانوار در شش سال گذشته چند برابر شد؟ / ف...  اقتصادی
# 24           صادرات واکسن "کوو ایران برکت" به ونزوئلا  اقتصادی
# 29                  تورم روپیه هند را به نابودی کشاند  اقتصادی
# 51  وزیر اقتصاد: کالای ته لنجی به رسمیت شناخته می‌شود  اقتصادی
# 52           صادرات گل‌گاوزبان از مازندران به پاکستان  اقتصادی
#
#                                              abstract  \
# 12  دهک دوم و اول (پایین‌ترین دهک‌های هزینه‌ای) بی...
# 24  ۱۰۰ هزار دوز واکسن «کوو ایران برکت» به ونزوئلا...
# 29  روپیه تاکنون در سال جاری بیش از ۶ درصد در براب...
# 51  خاندوزی افزود: به عبارتی معلوم شود که این اقلا...
# 52  آرام بخشی، درمان کم خونی، تهوع و درمان سرماخور...
#
#                                                  body
# 12  اقتصاد ایران طی چند سال گذشته یکی از شدیدترین ...
# 24  با امضای تفاهم نامه بین « اکبر برندگی » رئیس گ...
# 29  روپیه هند برای دومین جلسه متوالی به دلیل نگران...
# 51  احسان خاندوزی وزیر امور اقتصادی و دارایی در جر...
# 52  مدیر جهاد کشاوزی شهرستان نکا سید شبر موسوی با ...

# %%
value_specific_sports = df[df['subgroup']=='ورزشی']

# %%
value_specific_sports.head()
# Out:
#                                                  title subgroup  \
# 69           اولین زن عربستانی فعال در اتوکراس (+فیلم)    ورزشی
# 93                       بصره، میزبان جام خلیج فارس شد    ورزشی
# 97   اولین پیروزی تاریخ هندبال بانوان ایران در مساب...    ورزشی
# 123                    سید جلال حسینی مربی پرسپولیس شد    ورزشی
# 142            نادرترین دختر ملی‌پوش فوتبال جهان (عکس)    ورزشی
#
#                                               abstract  \
# 69   ایده تلاش برای رانندگی اتوکراس توسط زنان سعودی...
# 93   این رقابت ها هر دو سال یک بار با حضور ۸ کشور ع...
# 97   تیم هندبال جوانان ایران با پیروزی مقابل مکزیک ...
# 123  سید جلال حسینی کاپیتان ارزشمند تیم فوتبال پرسپ...
# 142  کارسون پیکت مدافع ۲۸ ساله آمریکایی که بدون داش...
#
#                                                   body
# 69   پس از اعطای گواهینامه رانندگی به زنان توسط عرب...
# 93   بیست و پنجمین دوره جام کشورهای حوزه خلیج فارس ...
# 97   تیم هندبال دختران ایران توانست با برتری برابر ...
# 123  قرارداد کاپیتان سابق پرسپولیس و محمد عسگری مرب...
# 142  فرارو: کارسون پیکوت به اولین بازیکن تاریخ فوتب...

# %%
value_specific_Cultural_artistic = df[df['subgroup']=='فرهنگی/هنری']

# %%
value_specific_Cultural_artistic.head()
# Out:
#                                                 title     subgroup  \
# 11  تمدید نظرسنجی مردمی جشنواره فیلم‌های ورزشی تا ...  فرهنگی/هنری
# 20  درگذشت یکی از تاثیرگذارترین کارگردانان تئاتر جهان  فرهنگی/هنری
# 32                 تکذیب انحلال باشگاه خبرنگاران جوان  فرهنگی/هنری
# 47  عذرخواهی خالق سریال معروف "فرندز" ؛ به نژادهای...  فرهنگی/هنری
# 53                     اکران «برادران لیلا» در فرانسه  فرهنگی/هنری
#
#                                              abstract  \
# 11  بهترین‌های ورزش تلویزیون در نظرسنجی سیزدهمین ج...
# 20  از بروک به عنوان یک نابغه در دنیای تئاتر یاد م...
# 32  باشگاه خبرنگاران جوان متعلق به صدا و سیما با ا...
# 47  پس از اتفاقی که برای جورج فلوید افتاد شروع کرد...
# 53  ترانه علیدوستی، نوید محمدزاده، سعید پورصمیمی، ...
#
#                                                  body
# 11  به گزارش روابط عمومی جشنواره، سیزدهمین جشنواره...
# 20  پیتر بروک اسطوره تئاتر جهان در سن ۹۷ سالگی درگ...
# 32  باشگاه خبرنگاران جوان متعلق به صدا و سیما با ا...
# 47  خالق سریال «فرندز» به خاطر بی‌توجهی به تنوع نژ...
# 53  همزمان با انتشار نخستین تیزر فیلم «برادران لیل...

# %%
value_specific_foreign_policy = df[df['subgroup']=='سیاست خارجی ']

# %%
value_specific_Events = df[df['subgroup']=='حوادث']

# %%
value_specific_Events.head()
# Out:
#                                                 title subgroup  \
# 8                     درگذشت دانشجوی دانشگاه فرهنگیان    حوادث
# 10      زاهدان/ غرق شدن 3 کودک در ظروف ذخیره آب خانگی    حوادث
# 16  زلزله شدید در هرمزگان/ تمام ادارات دولتی امروز...    حوادث
# 23           وقوع آتش‌سوزی در کیش ۵۰ درصد افزایش یافت    حوادث
# 27                پیکر ۳۵ شهید جامانده به کشور بازگشت    حوادث
#
#                                              abstract  \
# 8   "متین حبیب لی" دانشجومعلم رشته آموزش ابتدایی ۹...
# 10  گاهی مردم با قطعی آب روبه رو هستند. از این رو ...
# 16  دستگاه‌های و نهادهای امدادی، عملیاتی و خدمات ر...
# 23  حدود ۴۲ درصد از این ماموریت ها شامل ۷۱ فقره مر...
# 27  اجساد ۹ سرباز عراقی که در جنگ کشته شدند نیز تح...
#
#                                                  body
# 8   دانشگاه فرهنگیان با صدور پیامی، درگذشت یکی از ...
# 10  بر اثر افت فشار و یا قطعی آب در برخی نقاط حاشی...
# 16  ستاد بحران استانداری هرمزگان اعلام کرد: ادارات...
# 23  رییس اداره خدمات آتش نشانی و ایمنی جزیره کیش گ...
# 27  همزمان با سالروز شهادت امام جواد علیه السلام پ...

# %%
value_specific_health = df[df['subgroup']=='سلامت']

# %%
value_specific_health.head()
# Out:
#                                                  title subgroup  \
# 15                   بهترین منابع غذایی لیکوپن کدامند؟    سلامت
# 40   این 5 علامت روی دستتان خبر از بیماری قلبی می‌دهد!    سلامت
# 59    فوق تخصص مچ پا: کبودی و درد مچ پا را جدی بگیرید!    سلامت
# 79   اگر جای جوراب روی پایتان می ماند احتمالاً به ا...    سلامت
# 134       علائم خاموش بیماری قلبی در سنین بالای ۵۰ سال    سلامت
#
#                                               abstract  \
# 15   لیکوپن یکی از انواع کاروتنوئیدهاست که طیف رنگی...
# 40   اگر هر یک از این علائم را روی دستان خود مشاهده...
# 59                                                 NaN
# 79                                                 NaN
# 134  ورزش با افزایش سن اهمیت بیشتری پیدا می‌کند، زی...
#
#                                                   body
# 15   لیکوپن در گروه آنتی‌اکسیدان‌هایی قرار می‌گیرد ...
# 40   اگر چماقی شدن ناخن‌ها ناشی از بیماری قلبی باشد...
# 59                                                 NaN
# 79   اگر احساس کردید که جوراب‌های شما روی پایتان سف...
# 134  بیماری قلبی عامل اصلی مرگ در ایالات متحده است ...

# %%
value_specific_Reading_and_sightseeing = df[df['subgroup']=='خواندنی ها و دیدنی ها']

# %%
value_specific_Reading_and_sightseeing.head()
# Out:
#                                                 title               subgroup  \
# 37  خروج بی‌صدا از گروه‌های واتس‌اپ چه زمانی محقق ...  خواندنی ها و دیدنی ها
# 39       ناسا: خاک کره ماه متعلق به ماست، حراجش نکنید  خواندنی ها و دیدنی ها
# 41                   هشدار افتا درباره بدافزار چاپلین  خواندنی ها و دیدنی ها
# 42                 پیش‌غذای محبوب ایرانی‌ها، جهانی شد  خواندنی ها و دیدنی ها
# 44                          شنای یک کوسه در شب (فیلم)  خواندنی ها و دیدنی ها
#
#                                              abstract  \
# 37  خوشبختانه واتس‌اپ در حال کار برای رفع این معضل...
# 39  برگزارکننده حراجی اجازه ندارد اموالی را که هنو...
# 41  ​​​​​​​بدافزار جدیدی با نام چاپلین، به تازگی د...
# 42  سالاد شیرازی، به عنوان یک سالاد ملی در ایران ش...
# 44  در ویدئوی زیر تصویری بی‌نظیر از کوسه نهنگ Whal...
#
#                                                  body
# 37  شاید یک گروه قدیمی باشد، اما مدام با چت‌کردن ا...
# 39  حراجی گردوغبار ماه و سوسک‌هایی که خاک ماه را خ...
# 41  بدافزار چاپلین (Chaplin)، به‌تازگی در زیرساخت‌...
# 42  در اقدامی جالب و قابل توجه، صفحه رسمی مجله نیو...
# 44                                    منبع: برترین‌ها

# %%
value_specific_general = df[df['subgroup']=='عمومی']

# %%
value_specific_general.head()
# Out:
#                                                  title subgroup  \
# 0    پلیس: جرائم خشن و مسلحانه در تهران کاهش یافته است    عمومی
# 78                             زیباترین ملخ جهان (عکس)    عمومی
# 100          با ویژگی‌های میلگرد آجدار بیشتر آشنا شوید    عمومی
# 102                                       خرید پرشروسل    عمومی
# 202  سیرابی لاکچری از نمای نزدیک: با پنیر رنده شده ...    عمومی
#
#                                               abstract  \
# 0    آمارهای پلیس نشان می‌دهد که جرائم خشن و مسلحان...
# 78                                                 NaN
# 100                                                NaN
# 102                                                NaN
# 202                                                NaN
#
#                                                   body
# 0    رئیس پلیس آگاهی تهران بزرگ اعلام کرد که موضوع ...
# 78                                                 NaN
# 100                                                NaN
# 102  پرشروسل یا وسل به عنوان محفظه ممبران در دستگاه...
# 202                                                NaN

# %%
value_specific_Technology_and_IT = df[df['subgroup']=='فناوری و IT ']

# %%
value_specific_scientific = df[df['subgroup']=='علمی']

# %%
value_specific_scientific.head()
# Out:
#                                                  title subgroup  \
# 28   سالانه در کشور ۸۰ هزار نفر به فلج عصب صورت مبت...     علمی
# 98                               زنان احساساتی نیستند!     علمی
# 105              14 تیر؛ انتشار کلید سوالات کنکور 1401     علمی
# 372  دانشمندان ناسا: عکس‌های تلسکوپ جیمز وب نزدیک ب...     علمی
# 380  محققان می‌خواهند با ایجاد عمیق‌ترین حفره‌ها، ا...     علمی
#
#                                               abstract  \
# 28   در کشور ما تفاوت استانی در میزان شیوع این بیما...
# 98   مطالعه ای جدید نشان داده است که برخلاف باور عم...
# 105  طبق اعلام سازمان سنجش، کلید اولیه سوالات آزمون...
# 372  واقعاً سخت است که از دریچه‌ای جدید به جهان نگا...
# 380  این تیم سپس سال آینده عمق این حفره را دوباره 1...
#
#                                                   body
# 28   دبیر علمی سمپوزیوم دو روزه فلج عصب صورت با بیا...
# 98   محققان معتقد هستند که برخلاف کلیشه های جنسیتی ...
# 105  دفترچه سوالات کنکور سراسری ۱۴۰۱ گروه آزمایشی ز...
# 372  تلسکوپ جیمز وب اکنون مشغول ثبت نخستین تصاویرش ...
# 380  یک مهندس پژوهشگر از دانشگاه MIT از طریق پروژه‌...

# %%
value_specific_Psychology = df[df['subgroup']=='روانشناسی']

# %%
value_specific_Psychology.head()
# Out:
#                                              title   subgroup  \
# 43   نشانه‌هایی که خبر از قصد خودکشی دیگران می‌دهد  روانشناسی
# 260         علل، علایم، عوارض و درمان خشم فروخورده  روانشناسی
# 353                  تقویت مثبت و تقویت منفی چیست؟  روانشناسی
# 356    ۸ نشانه والدین سمی که باید از آنها آگاه بود  روانشناسی
# 425             6 اثر افسردگی بر زندگی شخصی و کاری  روانشناسی
#
#                                               abstract  \
# 43                                                 NaN
# 260  خشم فروخورده ، خشمی است که ناخودآگاه انکار می ...
# 353  هر عاملی که باعث رشد یا پیشرفت دانش آموز ( انس...
# 356  والدین سمی در اصطلاح به والدینی گفته می‌شود که...
# 425  افسردگی بازدارنده است و باعث می‌شود افراد به‌س...
#
#                                                   body
# 43   رئیس کمیته پیشگیری از خودکشی انجمن روان‌پزشکان...
# 260  کمک گرفتن از مشاور و درمان میتواند به افرد کمک...
# 353  در روانشناسی رفتاری یک تقویت، معرفی یک وضعیت م...
# 356  اگر روابط شما و فرزندتان آنطور که دوست دارید پ...
# 425  «افسردگی می‌تواند نظم زندگی را به‌ هم بزند و ش...

# %%
value_specific_health_news = df[df['subgroup']=='اخبار سلامت']

# %%
value_specific_health_news.head()
# Out:
#                                                  title     subgroup  \
# 1    وزیر بهداشت:\r\nآغاز اجرای طرح جامع "دارویار"/...  اخبار سلامت
# 65             روند ابتلا به کرونا در ایران افزایشی شد  اخبار سلامت
# 154  ذخیره استراتژیک بیش از ۴۰ میلیون دز واکسن کرون...  اخبار سلامت
# 248             خبر خوب/ کشف داروی درمانی برای ریزش مو  اخبار سلامت
# 258      کردستان/ تعداد مبتلایان به وبا به ۳۰ نفر رسید  اخبار سلامت
#
#                                               abstract  \
# 1    هدف اصلی وزارت بهداشت از این طرح این است که پو...
# 65   وزارت بهداشت: از همکاران پزشک خود درخواست می ک...
# 154  طبق قانون هر واکسنی که تولید شود، تاریخ انقضا ...
# 248  دانشمندان این را به عنوان شواهد بالینی امیدوار...
# 258  این افراد مبتلا کسانی هستند که سابقه مسافرت خا...
#
#                                                   body
# 1    وزیر بهداشت جزییات طرح "دارویار" که اجرای آن آ...
# 65   رئیس مرکز مدیریت بیماری های واگیر وزارت بهداشت...
# 154  عضو کمیته واکسیناسیون کرونا با اشاره به اینکه ...
# 248  دانشمندان به یک کشف کلیدی در مورد ریزش مو و ام...
# 258  معاون بهداشتی دانشگاه علوم پزشکی کردستان گفت: ...

# %%
value_specific_Environment = df[df['subgroup']=='محیط زیست']

# %%
value_specific_Environment.head()
# Out:
#                                                 title   subgroup  \
# 5            رونمایی از آمبولانس حیات وحش استان بوشهر  محیط زیست
# 224  انقراض نسل بیش از ۵۰۰ گونه جانوری در ۵۰ سال اخیر  محیط زیست
# 246         البرز/ وزش باد شدید و گردو خاک در پیش است  محیط زیست
# 681                     تلف شدن یک خرس قهوه‌ای در کرج  محیط زیست
# 734              احتمال اوج‌گیری مجدد غبار آلودگی هوا  محیط زیست
#
#                                               abstract  \
# 5    از همین رو پیشنهاد احداث یک واحد درمان و نقاهت...
# 224  به نظر پژوهشگران این موضوع که بیشتر این گونه‌ه...
# 246  احتمال  شکستگی درختان، آسیب به سقف خانه ها و س...
# 681  احداث روگذر یکی از تدابیری است که می تواند در ...
# 734  استان‌های سیستان وبلوچستان، خراسان جنوبی، سمنا...
#
#                                                   body
# 5    در آئینی با حضور مدیرعامل صندوق ملی محیط زیست،...
# 224  پژوهشگران اعلام کردند نسل بیش از ۵۰۰ گونه‌ حیو...
# 246  مدیرکل هواشناسی استان البرز اعلام کرد: از جمعه...
# 681  رییس اداره حفاظت محیط زیست شهرستان کرج از تلف ...
# 734  یک کارشناس هواشناسی با بیان اینکه گرد و غبار د...

# %%
value_specific_entertainment = df[df['subgroup']=='سرگرمی']

# %%
value_specific_entertainment.head()
# Out:
#                                                  title subgroup  \
# 552  عکسی کمیاب از بابی فیشر و رقابت همزمان با 50 نفر!   سرگرمی
# 601           اندازه جالب سیارات اگر میوه بودند! (عکس)   سرگرمی
# 680                یک نکته جالب در زبان انگلیسی! (عکس)   سرگرمی
# 771           نمایی دیدنی از هسته کهکشان راه شیری(عکس)   سرگرمی
# 792  نویسنده داستان‌های ترسناک چه فیلمی را نتوانست ...   سرگرمی
#
#                                               abstract  \
# 552  بابی فیشر استاد بزرگ شطرنج آمریکایی، در سال 19...
# 601                                                NaN
# 680                                                NaN
# 771  عکسی بسیار دیدنی از هسته کهکشان راه شیری که از...
# 792  «من در بزرگسالی تنها از دیدن ادامه یک فیلم منص...
#
#                                                   body
# 552                                                NaN
# 601                                                NaN
# 680                                                NaN
# 771                                                NaN
# 792  استیون کینگ، یکی از مشهورترین نویسندگان داستان...

# %%
value_specific_Download = df[df['subgroup']=='دانلود']

# %%
value_specific_Download.head()
# Out:
#                                                   title subgroup  \
# 441     دانلود بازی امپراطوری جهانی 2027 - World Empire   دانلود
# 3490      دانلود بازی ماینکرافت برای موبایل - Minecraft   دانلود
# 3498                 نرم افزار کنترل کامپیوتر (AnyDesk)   دانلود
# 6791    دانلود مرورگر موزیلا فایرفاکس - Mozilla Firefox   دانلود
# 7477  دانلود بازی زامبی ها و گیاهان - Plants vs Zomb...   دانلود
#
#                                                abstract  \
# 441   World Empire 2027 به شدت اعتیاد آور است و گیم ...
# 3490  در بازی Minecraft شما به صورت آزادانه به ساخت ...
# 3498  نرم افزار AnyDesk بسیار کم حجم و قابل حمل نیز ...
# 6791  آخرین نسخه مرورگر موزیلا فایرفاکس برای تمامی س...
# 7477  Plants vs Zombies حتی به خاطر محبوبیت بالا برا...
#
#                                                    body
# 441   World Empire 2027 یک بازی زیبا و سرگرم کننده د...
# 3490  از محبوب ترین، پرطرفدارترین و سرگرم کننده ترین...
# 3498  نرم افزار کاربردی که به شما امکان کنترل کامپیو...
# 6791                                                NaN
# 7477  که به صورت اختصار آن را PvZ 3 نیز می نامند، سو...

# %%
value_specific_Travel_and_entertainment = df[df['subgroup']=='سفر و تفریح']

# %%
value_specific_Travel_and_entertainment.head()
# Out:
#                                                   title     subgroup  \
# 1069  تسکالتوبو؛ شهری متروک اما جذاب برای مردم شوروی...  سفر و تفریح
# 2028  قارچ خور واقعی؛ هدیه نینتندو به طرفداران این خ...  سفر و تفریح
# 4083  تور مالزی، تور هند و تور تایلند مهم‌ترین مقاصد...  سفر و تفریح
# 4688                   رزرو بهترین هتل پنج ستاره در دبی  سفر و تفریح
# 6539  دعوت مالزی از گردشگران ایرانی: گردشگری حلال و ...  سفر و تفریح
#
#                                                abstract  \
# 1069  تسکالتوبو برای نخبگان حزب کمونیست از جمله ژوزف...
# 2028  قارچ خور معروف در ایران و یا دقیق تر بگوئیم با...
# 4083                                                NaN
# 4688                                                NaN
# 6539  مالزی در دو سال گذشته از فرصت استفاده کرد و بی...
#
#                                                    body
# 1069  زمانی که در سال 1991 فرو پاشید، شهر تفریحی در ...
# 2028  پارک موضوعی پس از سال ها توسعه و چند تاخیر سرا...
# 4083  کشورهای بسیار زیادی در آسیا هستند که برای سفر ...
# 4688                                                NaN
# 6539  مرزهای مالزی از حدود یک ماه پیش، پس از وقفه‌ای...

# %%
value_specific_short_story = df[df['subgroup']=='داستان کوتاه']

# %%
value_specific_short_story.head()
# Out:
#                                        title      subgroup  \
# 20326                     داستان ابزار شیطان  داستان کوتاه
# 25570  داستان حاکم، سیب، کشاورز و باقی قضایا  داستان کوتاه
# 33760        داستان کوتاه فقط یک سال زنده ای  داستان کوتاه
# 46046                       داستان بطری دارو  داستان کوتاه
# 51992                    داستان سیل در دهكده  داستان کوتاه
#
#                                                 abstract  \
# 20326  شیطان خود را به شکل چشمگیری به نمایش گذاشت. ای...
# 25570                                                NaN
# 33760  آنتونی برجس، (رمان‌نویس معروف انگلیسی) و دوبرا...
# 46046  پس از ۱۱ سال زوجی صاحب فرزند پسری شدند. آن دو ...
# 51992                                                NaN
#
#                                                     body
# 20326  گویند روزی شیطان همه جا جار زد که قصد دارد از ...
# 25570  روزی حاکمی در قصر نشسته بود که از بیرون قصر صد...
# 33760  آنتونی برجس ٤۰ ساله بود که دکترها به وی گفتند ...
# 46046  پس از ۱۱ سال زوجی صاحب فرزند پسری شدند. آن دو ...
# 51992  روزی به خاطر وقوع   زنان و کودکان   شیوانا، در...

# %%
value_specific_cooking = df[df['subgroup']=='آشپزی']

# %%
value_specific_cooking.head()
# Out:
#                                                    title subgroup  \
# 17516  طرز تهیه شیرینی خانگی برای عید نوروز (فیلم)/ ش...    آشپزی
# 20321                طرز تهیه خامه کیک با سفیده تخمه مرغ    آشپزی
# 48739                طرز تهیه تاکو؛ غذای پرطرفدار مکزیکی    آشپزی
# 52798          طرز تهیه اسموتی هندوانه؛ نوشیدنی تابستانی    آشپزی
# 53245                   طرز تهیه 2 نوع غذای رژیمی با مرغ    آشپزی
#
#                                                 abstract  \
# 17516      آموزش پخت شیرینی نخودچی خانگی برای عید نوروز.
# 20321  خامه کیک با سفیده تخمه مرغ یکی از روش های تهیه...
# 48739  تاکو انواع مختلفی دارد، اما چیزی که در بین همه...
# 52798  هندوانه، سرشار از ویتامین‌های C، A، B۱، B۵، B۶...
# 53245  وقتی صحبت از غذای رژیمی میشود مرغ یکی از اولین...
#
#                                                     body
# 17516                               منبع: مجله دیجی کالا
# 20321                                                NaN
# 48739  تاکو یک غذای محبوب و پرطرفدار مکزیکی است که می...
# 52798  اسموتی‌ها جزو پرطرفدارین نوشیدنی‌ها برای تابست...
# 53245  گوشت مرغ به نسبت کالری کمی که دارد مدت زمانی ط...

# %%
value_specific_Users = df[df['subgroup']=='کاربران']

# %%
value_specific_Users.head()
# Out:
#                                                   title subgroup  \
# 749     پیام مخاطبان/ فروش گوشی بدون رجیستر قانونی است؟  کاربران
# 815   پیام مخاطبان/ بانک صادرات و ملی دسترسی ایرانیا...  کاربران
# 2627  پیام مخاطبان/ صدای کتابداران کتابخانه های عموم...  کاربران
# 5676  پیام مخاطبان/ رفتار ناشایست کنسولگری ایرلند با...  کاربران
# 5816               پیام مخاطبان/ اتفاقی قشنگ در نانوایی  کاربران
#
#                                                abstract  \
# 749   اگر گوشی در طی این مدت آسیب دید و بعد از یک ما...
# 815   بانک ها با بستن صفحات خود در اینترنت مشکل اساس...
# 2627  جامعه کتابداران به مثابه یک بچه سر راهی می‌مانند.
# 5676  من تا به امروز بارها به سفارت های مختلف در داخ...
# 5816  خوشحالم در این اوضاع بیرحم آدم هایی با این تفک...
#
#                                                    body
# 749   چند روز پیش یه گوشی سامسونگ A03S از سایت دیجی ...
# 815   من مقیم کانادا هستم، قبلا به صورت آنلاین به حس...
# 2627  اینجانب عسگر محمدلو از کارکنان نهاد کتابخانه‌ه...
# 5676  به کنسولگری ایرلند در تهران برای تحویل مدارک د...
# 5816  یک اتفاقی برای من امروز افتاد که خیلی قشنگ بود...

# %%
value_specific_text_message = df[df['subgroup']=='پیامک']

# %%
value_specific_text_message.head()
# Out:
#                                              title subgroup abstract  \
# 43942                     اس ام اس تبریک روز سینما    پیامک      NaN
# 48732  اس ام اس تبریک روز بزرگداشت ابوريحان بيرونی    پیامک      NaN
# 52795                     اس ام اس تبریک عید قربان    پیامک      NaN
# 58130                   اس ام اس روز ملی گل و گیاه    پیامک      NaN
# 58307                        اس ام اس تبریک ازدواج    پیامک      NaN
#
#                                                     body
# 43942  21 شهریور روز ملی سینما بر همه ی اهالی سینما و...
# 48732  تعصب، چشم‌هاي‌ بینا را نابینا و گوش‌هاي‌ شنوا ...
# 52795  عید قربان گشته با یلدای طولانی به یک شب این عی...
# 58130  گل هدیه ای ست فرو فرستاده از بهشت مردم کریمتر ...
# 58307  ازدواج تنها پیوند زمینی است که در آسمانها بسته...
